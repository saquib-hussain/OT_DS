# %% [markdown]
# # Statistical Distributions

# %%
# Import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as st

# %% [markdown]
# #  Distributions / Probability Distributions

# %%
# Discrete Distributions
# 1. Bernoulli Distribution 
# 2. Binomial Distribution
# 3. Poission Distribution
# 4. Uniform Distribution

# %%
# %matplotlib inline

# %%
from scipy.stats import bernoulli
p = 0.3 # q = 0
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')

# %%
mean
# Out:
# array(0.3)

# %%
var
# Out:
# array(0.21)

# %%
skew
# Out:
# array(0.87287156)

# %%
kurt
# Out:
# array(-1.23809524)

# %%
from scipy.stats import binom

bdist = binom.rvs(size = 100, n=3, p = 0.5)
bdist
# Out:
# array([2, 1, 0, 3, 2, 2, 1, 1, 2, 1, 2, 1, 0, 2, 2, 2, 0, 2, 1, 1, 2, 1,
#        1, 2, 2, 2, 1, 2, 2, 2, 1, 0, 3, 3, 2, 1, 1, 2, 1, 2, 2, 2, 0, 2,
#        2, 3, 1, 1, 2, 1, 1, 1, 0, 2, 1, 2, 2, 1, 2, 0, 1, 2, 2, 2, 3, 1,
#        1, 0, 1, 2, 2, 2, 2, 1, 3, 3, 2, 2, 2, 1, 2, 3, 2, 0, 2, 2, 2, 1,
#        0, 3, 1, 1, 2, 2, 1, 1, 0, 1, 2, 2])

# %%
plt.plot(bdist)

# %% [markdown]
# # Uniform Distribution

# %%
from numpy import random
sns.distplot(random.uniform(size = 100), hist = False)
# Out:
# D:\Data\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Poisson Distribution

# %%
# Poisson Distribution
from scipy.stats import poisson

# %%
# Mean = 5, size = 20 
poisson.rvs(mu = 5, size = 20)
# Out:
# array([ 5,  7,  2,  4,  3,  4,  4,  2,  2,  3, 13,  4,  9,  7,  3,  4,  5,
#         2,  6,  8])

# %%
plt.plot(poisson.rvs(mu = 5, size = 20))

# %%
sns.distplot(random.poisson(lam = 25, size = 1000), kde = True)
# Out:
# D:\Data\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(random.poisson(lam = 1, size = 1000), kde = False)
# Out:
# D:\Data\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
sns.distplot(random.poisson(lam = 2, size = 1000), kde = False)
# Out:
# D:\Data\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>
