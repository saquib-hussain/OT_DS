# %%
# Functionalies of offered by Pandas
# read_csv, excel, zip, txt, json, xml, html, images, pdf, mp3, mp4

# %%
# Functions 
# head(), tail(), date_range(), DataFrame(), Series(), copy(),min(), max(), 
# Slicing Dicing

# %%
import numpy as np
import pandas as pd

# %%
df4 = pd.read_csv(r"C:\Users\Moushmi\Desktop\airline-safety.csv")

# %%
df4.head(10)
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
# 5             Air France              3004002661               14
# 6             Air India*               869253552                2
# 7       Air New Zealand*               710174817                3
# 8       Alaska Airlines*               965346773                5
# 9               Alitalia               698012498                7
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# ...

# %%
df4.tail(3)
# Out:
#              airline  avail_seat_km_per_week  incidents_85_99  \
# 53  Vietnam Airlines               625084918                7
# 54   Virgin Atlantic              1005248585                1
# 55   Xiamen Airlines               430462962                9
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 53                      3               171                1
# 54                      0                 0                0
# 55                      1                82                2
#
#     fatal_accidents_00_14  fatalities_00_14
# 53                      0                 0
# 54                      0                 0
# 55                      0                 0

# %%
df = pd.DataFrame({'list1':[1,2,3,4],'list2':[5,6,7,8], 'list3':[9,10,11,12] })

# %%
df
# Out:
#    list1  list2  list3
# 0      1      5      9
# 1      2      6     10
# 2      3      7     11
# 3      4      8     12

# %%
df.iloc[:,0:1]
# Out:
#    list1
# 0      1
# 1      2
# 2      3
# 3      4

# %%
df.iloc[:3] # Only slicing from beginning
# Out:
#    list1  list2  list3
# 0      1      5      9
# 1      2      6     10
# 2      3      7     11

# %%
df.iloc[0:3,1:3]
# Out:
#    list2  list3
# 0      5      9
# 1      6     10
# 2      7     11

# %%
df.iloc[0]  # Indexing by row only
# Out:
# list1    1
# list2    5
# Name: 0, dtype: int64

# %%
df4.iloc[0]
# Out:
# airline                   Aer Lingus
# avail_seat_km_per_week     320906734
# incidents_85_99                    2
# fatal_accidents_85_99              0
# fatalities_85_99                   0
# incidents_00_14                    0
# fatal_accidents_00_14              0
# fatalities_00_14                   0
# Name: 0, dtype: object

# %%
df4.iloc[:,0:1]
# Out:
#                        airline
# 0                   Aer Lingus
# 1                    Aeroflot*
# 2        Aerolineas Argentinas
# 3                  Aeromexico*
# 4                   Air Canada
# 5                   Air France
# 6                   Air India*
# 7             Air New Zealand*
# 8             Alaska Airlines*
# 9                     Alitalia
# 10          All Nippon Airways
# 11                   American*
# 12           Austrian Airlines
# 13                     Avianca
# 14            British Airways*
# 15             Cathay Pacific*
# 16              China Airlines
# 17                      Condor
# 18                        COPA
# 19          Delta / Northwest*
# 20                    Egyptair
# 21                       El Al
# 22          Ethiopian Airlines
# 23                     Finnair
# 24            Garuda Indonesia
# 25                    Gulf Air
# 26           Hawaiian Airlines
# 27                      Iberia
# 28              Japan Airlines
# ...

# %%
df
# Out:
#    list1  list2  list3
# 0      1      5      9
# 1      2      6     10
# 2      3      7     11
# 3      4      8     12

# %%
# dataframe.loc[row,col]

# %%
df1 = pd.DataFrame([[1,True],[2,False],[3,True]],['Mercy','Saquib','Sugandhi'])

# %%
df1
# Out:
#           0      1
# Mercy     1   True
# Saquib    2  False
# Sugandhi  3   True

# %%
# Index of Dataframe

# %%
df5 = pd.DataFrame([[10,20,30],[40,50,60],[70,80,90]], index = ['Saquib', 'Mercy','Sugandhi'], columns =['A','B','C'])
df5
# Out:
#            A   B   C
# Saquib    10  20  30
# Mercy     40  50  60
# Sugandhi  70  80  90

# %%
df5.loc['Saquib']
# Out:
# A    10
# B    20
# C    30
# Name: Saquib, dtype: int64

# %%
df5.loc['Saquib':'Sugandhi']
# Out:
#            A   B   C
# Saquib    10  20  30
# Mercy     40  50  60
# Sugandhi  70  80  90

# %%
# DataFrame.Index

# %%
df5.index
# Out:
# Index(['Saquib', 'Mercy', 'Sugandhi'], dtype='object')

# %%
# empty

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.empty
# Out:
# True

# %%
df4.empty
# Out:
# False

# %%
# DataFrame ndim

# %%
df4.ndim
# Out:
# 2

# %%
# The information about the DataFrame
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   airline                 56 non-null     object
#  1   avail_seat_km_per_week  56 non-null     int64
#  2   incidents_85_99         56 non-null     int64
#  3   fatal_accidents_85_99   56 non-null     int64
#  4   fatalities_85_99        56 non-null     int64
#  5   incidents_00_14         56 non-null     int64
#  6   fatal_accidents_00_14   56 non-null     int64
#  7   fatalities_00_14        56 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 3.6+ KB

# %%
df4.describe()
# Out:
#        avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# count            5.600000e+01        56.000000              56.000000
# mean             1.384621e+09         7.178571               2.178571
# std              1.465317e+09        11.035656               2.861069
# min              2.593733e+08         0.000000               0.000000
# 25%              4.740362e+08         2.000000               0.000000
# 50%              8.029089e+08         4.000000               1.000000
# 75%              1.847239e+09         8.000000               3.000000
# max              7.139291e+09        76.000000              14.000000
#
#        fatalities_85_99  incidents_00_14  fatal_accidents_00_14  \
# count         56.000000        56.000000              56.000000
# mean         112.410714         4.125000               0.660714
# std          146.691114         4.544977               0.858684
# min            0.000000         0.000000               0.000000
# ...

# %%
df4.describe().T
# Out:
#                         count          mean           std          min  \
# avail_seat_km_per_week   56.0  1.384621e+09  1.465317e+09  259373346.0
# incidents_85_99          56.0  7.178571e+00  1.103566e+01          0.0
# fatal_accidents_85_99    56.0  2.178571e+00  2.861069e+00          0.0
# fatalities_85_99         56.0  1.124107e+02  1.466911e+02          0.0
# incidents_00_14          56.0  4.125000e+00  4.544977e+00          0.0
# fatal_accidents_00_14    56.0  6.607143e-01  8.586837e-01          0.0
# fatalities_00_14         56.0  5.551786e+01  1.113328e+02          0.0
#
#                                  25%          50%           75%           max
# avail_seat_km_per_week  4.740362e+08  802908893.0  1.847239e+09  7.139291e+09
# incidents_85_99         2.000000e+00          4.0  8.000000e+00  7.600000e+01
# fatal_accidents_85_99   0.000000e+00          1.0  3.000000e+00  1.400000e+01
# fatalities_85_99        0.000000e+00         48.5  1.842500e+02  5.350000e+02
# ...

# %%
df4.head(4)
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# 3                      0                 0

# %%
# At is used with row index and column name
df4.at[0,'airline']
# Out:
# 'Aer Lingus'

# %%
df4.at[1,'incidents_85_99']
# Out:
# 76

# %%
df4.shape
# Out:
# (56, 8)

# %%
df6 = df4.query('incidents_85_99 >50')
df6
# Out:
#      airline  avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# 1  Aeroflot*              1197672318               76                     14
#
#    fatalities_85_99  incidents_00_14  fatal_accidents_00_14  fatalities_00_14
# 1               128                6                      1                88

# %%
df7 = df4.query('incidents_85_99 >10')
df7
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 1                    Aeroflot*              1197672318               76
# 5                   Air France              3004002661               14
# 11                   American*              5228357340               21
# 16              China Airlines               813216487               12
# 19          Delta / Northwest*              6525658894               24
# 22          Ethiopian Airlines               488560643               25
# 31                  Korean Air              1734522605               12
# 51       United / Continental*              7139291291               19
# 52  US Airways / America West*              2455687887               16
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 1                      14               128                6
# 5                       4                79                6
# 11                      5               101               17
# ...

# %%
df8 = df4.query('incidents_85_99 ==0')
df8
# Out:
#                airline  avail_seat_km_per_week  incidents_85_99  \
# 15     Cathay Pacific*              2582459303                0
# 26   Hawaiian Airlines               493877795                0
# 48  TAP - Air Portugal               619130754                0
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 15                      0                 0                2
# 26                      0                 0                1
# 48                      0                 0                0
#
#     fatal_accidents_00_14  fatalities_00_14
# 15                      0                 0
# 26                      0                 0
# 48                      0                 0

# %%
df5
# Out:
#            A   B   C
# Saquib    10  20  30
# Mercy     40  50  60
# Sugandhi  70  80  90

# %%
df4.drop(index = 1, inplace = True)

# %%
df4.shape
# Out:
# (55, 8)

# %%
df4.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
# 5             Air France              3004002661               14
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
# 5                      4                79                6
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 2                      0                 0
# 3                      0                 0
# ...
