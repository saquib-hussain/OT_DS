# %% [markdown]
# # Introduction to Pandas

# %%
import numpy as np
import pandas as pd

# %%
# Creating Series 
heights = pd.Series([6.5,5.9,5.2,5.0], name= "Heights")
heights
# Out:
# 0    6.5
# 1    5.9
# 2    5.2
# 3    5.0
# Name: Heights, dtype: float64

# %%
heights.max()
# Out:
# 6.5

# %%
list = ["name",34,5.0,True]

# %%
mySeries = pd.Series(list)

# %%
mySeries
# Out:
# 0    name
# 1      34
# 2       5
# 3    True
# dtype: object

# %%
dict1 = {"name":"Manoj", "Age":"23","city":"Chennai"}
dict2 = {"name":"Mercy", "Age":"23","city":"Chennai"}

# %%
ManojSeries = pd.Series(dict1)

# %%
ManojSeries
# Out:
# name      Manoj
# Age          23
# city    Chennai
# dtype: object

# %%
MultiSeries = pd.Series(dict2)
MultiSeries
# Out:
# name      Mercy
# Age          23
# city    Chennai
# dtype: object

# %%
df = pd.DataFrame(dict1, dict2)

# %%
df
# Out:
#        name Age     city
# name  Manoj  23  Chennai
# Age   Manoj  23  Chennai
# city  Manoj  23  Chennai

# %%
listname = ["Manoj","Mercy"]

# %%
listage = [23,22]
listcity = ["Chennai","Chennai"]

# %%
dict1 = {"name":listname, "Age":listage, "City":listcity}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name  Age     City
# 0  Manoj   23  Chennai
# 1  Mercy   22  Chennai

# %%
df1 = pd.DataFrame([dict1,dict2])

# %%
df1
# Out:
#              name       Age                City     city
# 0  [Manoj, Mercy]  [23, 22]  [Chennai, Chennai]      NaN
# 1           Mercy        23                 NaN  Chennai

# %%
# Work with dates

datedata = pd.date_range("20220301", periods = 5)

# %%
datedata
# Out:
# DatetimeIndex(['2022-03-01', '2022-03-02', '2022-03-03', '2022-03-04',
#                '2022-03-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
import time

# %%
df3 = pd.DataFrame(np.random.randn(5,4), index = datedata, columns=['a', 'b', 'c','d'])

# %%
df3
# Out:
#                    a         b         c         d
# 2022-03-01  0.007141  0.955324 -1.056015  0.725156
# 2022-03-02  1.354064  0.168085 -1.087692  0.146382
# 2022-03-03 -1.384588  0.320624  1.763876  0.232568
# 2022-03-04 -0.939185  0.565495  2.404023  1.068654
# 2022-03-05  0.194627  0.059800  1.461525 -0.612065

# %%
# Loading a csv file via pandas

# %%
df4 = pd.read_csv(r"C:\Users\Moushmi\Desktop\airline-safety.csv")

# %%
df4
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
df5 = pd.read_csv("airline-safety.csv")
df5.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# ...
